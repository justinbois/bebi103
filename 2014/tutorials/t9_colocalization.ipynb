# %% [markdown]
# # Tutorial 9a: Colocalization

# %% [markdown]
# *This tutorial was generated from an IPython notebook.  You can download the notebook [here](t9a_colocalization.ipynb).*

# %% [markdown]
# In this tutorial, we will learn about **colocalization**.  In a colocalization study, we seek to answer the question: Are two fluorescent proteins spacially proximal in a cell?  You can download the data set [here](http://bebi103.caltech.edu/2014/protected/data/ramesh_et_al.zip).  You should also download [`jb_costes.py`](http://bebi103.caltech.edu/2014/handouts/jb_costes.py), a module I wrote to do colocalization using the [Costes method](http://bebi103.caltech.edu/2014/protected/papers/costes_2004.pdf).

# %% [markdown]
# Before we begin, we import our favorite modules, as always.

# %%
# As usual, import modules
from __future__ import division, absolute_import,  print_function

import os
import random

import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from matplotlib import cm
import skimage.io
import skimage.filter

# Utilities from JB
import jb_utils as jb

# Module to do Costes localization
import jb_costes

# Necessary to display plots in this IPython notebook
# %matplotlib inline

# %% [markdown]
# ## The data set

# %% [markdown]
# The data set comes form Pradeep's research in the [Shapiro lab](http://shapirolab.caltech.edu) here at Caltech.  He is working on inserting a genetic program for a set of proteins responsible for construction of magnetosomes in magnetotactic bacteria into mammalian cells.  The magnetic particles could then be used in magnetic resonance imaging.
#
# In the early phases of this work, Pradeep is investigating the localization of the proteins of interest in the mammalian cells.  He is using HEK293T (human embryonic kidney) cells expressing the following proteins:
# 1. *mamP*: changes the oxidation state of iron from Fe$2+$ to weakly magnetic oxidized iron species.
# 2. *mamB*: A membrane-bound cation transport facilitator.
# 3. *mamM*: Also a membrane-bound cation transport facilitator.
#
# In the images we will work with today, the cells were fixed and then stained with anitbodies to image the endoplasmic reticulum and mitochondria.  The cells were also stained with DAPI to label nuclei.  Finally, the mam proteins have an epitope tag (HA), which is used in the antibody staining to identify mamB, mamB, and mamM a green fluorophore.
#
# The data set then has the following files:
# 1. `mamB-antiHA-antiCOX4-xxx-y.ome.tiff`:  Here `y` is just the number of the repeat of the experiment.  `xxx` = `488` for labeling of mamB; `xxx` = `543` for labeling of COX4 (cytochrome oxidase), which resides in the inner membranes of mitochondria; and `xxx` = `DAPI` for DAPI staining.
# 2. `mamB-antiHA-antiCalnexin-xxx-y.ome.tiff`: `xxx` = `488` for labeling of mamB; `xxx` = `543` for labeling of Calnexin (a calcium-binding protein in the ER); and `xxx` = `DAPI` for DAPI staining.
# 3. `mamP-xxx-antiHA-y.ome.tiff`: `xxx` = `488` for labeling of mamP; `xxx` = `650` for labeling of Calnexin; and `xxx` = `DAPI` for DAPI staining.
# 4. `mamP_minusSRP-xxx-antiHA-y.ome.tiff`: `xxx` = `488` for labeling of mamP that is missing a SRP (signal recognition particle which translocates certain ribosome/mRNA complexes into the ER); `xxx` = `650` for labeling of Calnexin; and `xxx` = `DAPI` for DAPI staining.
#
# We will use the first set of images to investigate if the mamB localizes to the mitochondria, the second set to see is mamB localizes to the ER, the third to see if mamP localizes to the ER, and, if so, we will use the fourth set to see if that localization is dependent on the SRP.

# %% [markdown]
# ## Visualizing colocalization

# %% [markdown]
# A commonly used and quick-and-dirty way to visualize colocalization is to merge the channels and look at the images together.  If, say, green and red channels have high intensities at the same place, that location will appear yellow.  As we'll discuss below, this should be done with great caution, and there are better ways to visualize colocalization!
#
# We will start with the mamB/COX4 images.

# %%
data_dir = '../data/ramesh_et_al'

# Define file names
fname_g = os.path.join(data_dir, 'mamB-antiHA-antiCOX4-488-1.ome.tiff')
fname_r = os.path.join(data_dir, 'mamB-antiHA-antiCOX4-543-1.ome.tiff')
fname_b = os.path.join(data_dir, 'mamB-antiHA-antiCOX4-DAPI-1.ome.tiff')

# Load three channels
im_r = skimage.io.imread(fname_r)
im_g = skimage.io.imread(fname_g)
im_b = skimage.io.imread(fname_b)

# %% [markdown]
# We will make a merged image for the purposed of visualization.  We should code the images in cyan, magenta, and yellow for colorblind people.

# %%
def im_merge(im_cyan, im_magenta, im_yellow=None):
    """
    Merge channels to make RGB image that has cyan, magenta, and yellow.
    """
    im_cyan_scaled = (im_cyan - im_cyan.min()) \
                            / (im_cyan.max() - im_cyan.min())
    im_magenta_scaled = (im_magenta - im_magenta.min()) \
                            / (im_magenta.max() - im_magenta.min())
    
    if im_yellow is None:
        im_yellow_scaled = np.zeros_like(im_cyan)
    else:
        im_yellow_scaled = (im_yellow - im_yellow.min()) \
                                / (im_yellow.max() - im_yellow.min())

    # Convert images to RGB with magenta, cyan, and yellow channels
    im_cyan_scaled_rgb = np.dstack((np.zeros_like(im_cyan_scaled),
                                    im_cyan_scaled, 
                                    im_cyan_scaled))
    im_magenta_scaled_rgb = np.dstack((im_magenta_scaled, 
                                       np.zeros_like(im_magenta_scaled),
                                       im_magenta_scaled))
    im_yellow_scaled_rgb = np.dstack((im_yellow_scaled, 
                                      im_yellow_scaled, 
                                      np.zeros_like(im_yellow_scaled)))

    # Merge together
    merged_image = im_cyan_scaled_rgb + im_magenta_scaled_rgb \
                        + im_yellow_scaled_rgb

    # Scale each channel to be between zero and 1
    merged_image[:,:,0] /= merged_image[:,:,0].max()
    merged_image[:,:,1] /= merged_image[:,:,1].max()
    merged_image[:,:,2] /= merged_image[:,:,2].max()
    
    return merged_image

# %% [markdown]
# With this handy function in had, we can view our merge.

# %%
# Make merged image
merged_image = im_merge(im_g, im_r, im_b)

# Show the images
figure, ax = plt.subplots(2, 2, figsize=(12, 12))
ax[0,0].imshow(im_r, cmap=cm.gray)
ax[0,1].imshow(im_g, cmap=cm.gray)
ax[1,0].imshow(im_b, cmap=cm.gray)
ax[1,1].imshow(merged_image)

ax[0,0].set_title('anit-COX4')
ax[0,1].set_title('anti-HA')
ax[1,0].set_title('DAPI')
ax[1,1].set_title('merged')

# %% [markdown]
# The "eye test" says that the mitochondria (in red) are separate and apart from the nuclei (which we don't really care about here) and the mamB.  But, the eye test is not careful science!  We need to have a **quantification** for colocalization.

# %% [markdown]
# ## Quantifying colocalization

# %% [markdown]
# There are many ways to quantify colocalization.  We will try a number of things, eventually landing on the [Costes method](http://bebi103.caltech.edu/2014/protected/papers/costes_2004.pdf) with ROIs.

# %% [markdown]
# ### 2D histograms

# %% [markdown]
# To start our quantification, we "plot" our image in a different way.  On the $x$-axis is pixel values in the red (COX4) channel.  On the $y$-axis is pixel values for the green (mamB) channel.  We then plot each pixel as a point on these axes.  This is often called a 2D-histogram.  That name is more appropriate when we color the plotted pixels according to counts, which we will not do here for simplicity.

# %%
# Plot 2D histogram
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
ax.plot(im_r.ravel(), im_g.ravel(), 'k.', alpha=0.2)
plt.xlabel('anti-HA')
plt.ylabel('anit-COX4')
ax.set_xlim((0, 4095))
ax.set_ylim((0, 4095))
# Out:
# (0, 4095)

# %% [markdown]
# The lower right corner of this plot is the low-intensity pixels.  A signature of colocalization is lots of pixels in the upper right corner. Large number of pixels in the other corners are a signature of exclusion.  So, the histogram tells us that there is likely not colocalization.  But, we still need to quantify it!

# %% [markdown]
# ### ICCB analysis

# %% [markdown]
# ICCB, or **image correlation coefficient-based** methods for colocalization analysis give a powerful way to quantify colocalization.  The idea is to compute a **correlation coefficient** for the two images.  This should be independent of the absolute scale pixel intensities.  The **Pearson correlation coefficient** works well for this purpose.  For images $I_1$ and $I_2$, it can be computed as
#
# \begin{align}
# r = \frac{\sum_i\left(I_{1,i} - \bar{I}_1\right)\left(I_{2,i} - \bar{I}_2\right)}{\sqrt{\left(\sum_i \left(I_{1,i} - \bar{I}_1\right)^2\right)\left(\sum_i \left(I_{2,i} - \bar{I}_2\right)^2\right)}}.
# \end{align}
#
# The Pearson $r$ ranges from $-1$ to $1$, where $r = -1$ means exclusion, $r=0$ means independence, and $r=1$ means colocalization.  Fortunately, `scipy.stats.pearsonr` does the calculation for us!  Let's put this to work!

# %%
# Compute Pearson correlation coefficient
r, p = scipy.stats.pearsonr(im_r.ravel(), im_g.ravel())

# Print result
print('Pearson r = ', r)
# Out:
# Pearson r =  0.255484536045

# %% [markdown]
# Ok.  Pearson $r$ is 0.26.  What does that mean!?  Is it colocalized?  To answer this question, we need a basis for comparison.

# %% [markdown]
# ## Costes's method

# %% [markdown]
# To see if we actually have colocalization, we need to compare the Pearson $r$ to something.  Costes and coworkers proposed repeatedly scrambling one of the images, and then computing the Pearson $r$ between the scrambled image and the original image of the other.  This way, we see if the colocalization is more likely than random chance.
#
# We know that neighboring pixels are not independent of each other because of the finite width of the point spread function.  We therefore should scramble blocks of the image that are the same size of the PSF.  To do this, we first need to make the image have dimensions that are a multiple of the width of the PSF.  We will do this by mirroring the edges of the image.

# %%
def mirror_edges(im, psf_width, roi=None):
    """
    Given a 2D image im, pads the boundaries by mirroring so that the
    dimensions of the image are a multiple of psf_width.
    
    Also pads an "image" containing the ROI if necessary.
    """
    
    # How much we need to pad
    pad_i = psf_width - (im.shape[0] % psf_width)
    pad_j = psf_width - (im.shape[1] % psf_width)

    # Get widths
    pad_top = pad_i // 2
    pad_bottom = pad_i - pad_top
    pad_left = pad_j // 2
    pad_right = pad_j - pad_left

    # Do the padding
    im_pad = np.pad(im, ((pad_top, pad_bottom), (pad_left, pad_right)),
                    mode='reflect')

    if roi is None:
        return im_pad
    else:
        roi_pad = np.pad(roi, ((pad_top, pad_bottom), (pad_left, pad_right)),
                         mode='reflect')
        return im_pad, roi_pad

# %% [markdown]
# We'll now mirror `im_r` and `im_g` at their edges.  When we view the result, we see that we only added a single pixel in each dimension.

# %%
# Specify PSF width
psf_width = 3

# Mirror edges
im_r_mirror = mirror_edges(im_r, psf_width)
im_g_mirror = mirror_edges(im_g, psf_width)

# Show the images
figure, ax = plt.subplots(1, 2, figsize=(12, 8))
ax[0].imshow(im_r_mirror, cmap=cm.gray)
ax[1].imshow(im_g_mirror, cmap=cm.gray)

ax[0].set_title('anit-COX4')
ax[1].set_title('anti-HA')

# %% [markdown]
# Next, we can convert the image to a list of 3$\times$3 (or PSF width $\times$ PSF width) blocks.  We will write the function in a general way such that we can also specify an ROI and only keep blocks belonging to the ROI.

# %%
def im_to_blocks(im, width, roi=None, roi_method='all'):
    """
    Converts image to list of blocks.  If roi is not None, only keeps blocks
    that are within an ROI.  The test for being within and ROI is either
    'all' (all pixels much be in ROI) or 'any' (a block is in the ROI if
    any of its pixels are in the ROI).
    """
    # Initialize ROI
    if roi is None:
        roi = np.ones_like(im)

    # Specify method for determining if in ROI or not
    if roi_method == 'all':
        roi_test = np.all
    else:
        roi_test = np.any

    # Construct list of blocks
    blocks = []
    for i in range(0, im.shape[0], width):
        for j in range(0, im.shape[1], width):
            if roi_test(roi[i:i+width, j:j+width]):
                blocks.append(im[i:i+width, j:j+width])

    return blocks

# %% [markdown]
# We have to remember to use the images with mirrored edges with computing the blocks.

# %%
# Get blocks of red and green channels
blocks_r = im_to_blocks(im_r_mirror, psf_width)
blocks_g = im_to_blocks(im_g_mirror, psf_width)

# Store green blocks as flattened array since we don't scramble them
blocks_g_flat = np.array(blocks_g).flatten()

# %% [markdown]
# We can compute the Pearson $r$ value from the blocks to verify that it's the same as before (a good bug check).

# %%
# Get r value for unscrambled images
r_unscr, p = scipy.stats.pearsonr(np.array(blocks_r).ravel(), blocks_g_flat)

# Print the value
print('unscrambled r =', r_unscr)
# Out:
# unscrambled r = 0.255269337203

# %% [markdown]
# Now we'll scramble the red image and measure the Pearson $r$ value for each scrambled image.  We'll keep it in an array, `r_scr`.

# %%
def scrambled_r(n_scramble, blocks_1, blocks_2_flat):
    """
    Scrambles blocks_1 n_scramble times and returns the Pearson r values.
    """
    r_scr = np.empty(n_scramble)
    for i in range(n_scramble):
        random.shuffle(blocks_1)
        r, p = scipy.stats.pearsonr(np.array(blocks_1).ravel(), 
                                    blocks_2_flat)
        r_scr[i] = r
    return r_scr

# Do the scamblin'!
n_scramble = 200
r_scr = scrambled_r(n_scramble, blocks_r, blocks_g_flat)

# %% [markdown]
# We can plot the histogram to see what $r$ values we might expect from random pixel locations.

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

# Plot histogram
n, b, p = ax.hist(r_scr, bins=np.sqrt(n_scramble), normed=True)

# Plot computed r
ax.plot([r_unscr, r_unscr], ax.get_ylim(), 'r-')

# Label axes
ax.set_xlabel('Pearson $r$')

# %% [markdown]
# We see that there is no way random pixels would give us the corrlelation coefficient we've measured in the unscrambled images.  But this doesn't seem to make any sense!  We saw in the eye test that these things are not colocalized.
#
# The problem lies in the fact that we are considering background as well.  We have in a way proven that both mamB and mitochondria are located in cells.  We would like to see if they are colocalized in cells.  We therefore need to define an ROI to consider that is just cells.

# %% [markdown]
# ### Defining an ROI for cells

# %% [markdown]
# We can do colocalization analysis after segmenting and defining an ROI.  For this purpose, we will do a simple thresholding techinque.  Specifically, we will use Yen's method to define a global threshold in both channels.  We will consider any pixel that has either the red or green channel above the respective threshold as part of the ROI.  We will also clean up and delete any small pieces of the image that are smaller than the width of the PSF.

# %%
# Determine ROI by global thresholding using Yen's method
thresh_r = skimage.filter.threshold_yen(im_r)
thresh_g = skimage.filter.threshold_yen(im_g)

# Make ROI mask
roi = (im_r > thresh_r) | (im_g > thresh_g)
roi = skimage.morphology.remove_small_objects(roi, min_size=9)

# View the ROI
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
ax.imshow(roi, cmap=cm.gray)

# %% [markdown]
# We still need to mirror the edges of the ROI so we can use it to make our new blocks based on this ROI.

# %%
# Make mirrored ROI
roi_mirror = mirror_edges(roi, psf_width)

# %% [markdown]
# Let's look at what this did to the histogram.

# %%
# Plot histogram
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
ax.plot((im_r[roi]).ravel(), (im_g[roi]).ravel(), 'k.', alpha=0.2)
plt.xlabel('anti-HA')
plt.ylabel('anit-COX4')
ax.set_xlim((0, 4095))
ax.set_ylim((0, 4095))
# Out:
# (0, 4095)

# %% [markdown]
# Let's redo the colocalization analysis.

# %%
# Get blocks of red and green channels
blocks_r = im_to_blocks(im_r_mirror, psf_width, roi=roi_mirror)
blocks_g = im_to_blocks(im_g_mirror, psf_width, roi=roi_mirror)

# Store blocks as flattened array in case we don't want to scramble them
blocks_g_flat = np.array(blocks_g).flatten()

# Get r value for unscrambled images
r_unscr, p = scipy.stats.pearsonr(np.array(blocks_r).ravel(), blocks_g_flat)

# Do the scamblin'!
n_scramble = 200
r_scr = scrambled_r(n_scramble, blocks_r, blocks_g_flat)

# Compute how sure we are that it's colocalized
p_coloc = (r_scr < r_unscr).sum() / n_scramble

# Print the values
print('unscrambled r =', r_unscr)
print('prob. of colocalization =', p_coloc)
# Out:
# unscrambled r = -0.485908111081
# prob. of colocalization = 0.0

# %% [markdown]
# We see that those low intensity pixels (there were many of them) strongly biased our colocalization analysis.  In fact, mamB avoids the mitochonria!

# %% [markdown]
# ## An example with colocalization

# %% [markdown]
# Let's now consider colocalization analysis with mamP and the ER.

# %%
data_dir = '../data/ramesh_et_al'

# Define file names
fname_g = os.path.join(data_dir, 'mamP-488-antiHA-3.ome.tiff')
fname_r = os.path.join(data_dir, 'mamP-650-antiHA-3.ome.tiff')
fname_b = os.path.join(data_dir, 'mamP-DAPI-antiHA-3.ome.tiff')

# Load three channels
im_r = skimage.io.imread(fname_r)
im_g = skimage.io.imread(fname_g)
im_b = skimage.io.imread(fname_b)

# Display the images
merged_image = im_merge(im_g, im_r, im_b)

# Show the images
figure, ax = plt.subplots(2, 2, figsize=(12, 12))
ax[0,0].imshow(im_r, cmap=cm.gray)
ax[0,1].imshow(im_g, cmap=cm.gray)
ax[1,0].imshow(im_b, cmap=cm.gray)
ax[1,1].imshow(merged_image)

ax[0,0].set_title('anit-Calnexin')
ax[0,1].set_title('anti-HA')
ax[1,0].set_title('DAPI')
ax[1,1].set_title('merged')

# %% [markdown]
# Let's perform the colocalization analysis.  Conveniently, I have written all colocalization the steps for you!  We'll use the `jb_costes` module.  We will not compute Manders coefficients now, but will discuss them later.  So, we just need to compute the ROI and then do the analysis.

# %%
# Compute ROI
thresh_r = skimage.filter.threshold_yen(im_r)
thresh_g = skimage.filter.threshold_yen(im_g)
roi = (im_r > thresh_r) | (im_g > thresh_g)
roi = skimage.morphology.remove_small_objects(roi, min_size=9)

# Use costes module to perform colocalization
coloc = jb_costes.costes_coloc(im_r, im_g, n_scramble=200, psf_width=3,
                               do_manders=False, roi=roi, roi_method='all')

# %% [markdown]
# The results are stored in the `coloc` object.  We can see what is has using the `coloc.__dict__` attribute.  Note that many of the attributes are `None` since we haven't compute the Manders coefficients yet.

# %%
coloc.__dict__.keys()
# Out:
# ['a',
#  'thresh_2',
#  'pearson_r',
#  'b',
#  'r_scr',
#  'thresh_r',
#  'thresh_1',
#  'psf_width',
#  'n_scramble',
#  'p_coloc',
#  'M_2',
#  'M_1']

# %% [markdown]
# Let's check the probability of colocalization.

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))

# Plot histogram
n, b, p = ax.hist(coloc.r_scr, bins=np.sqrt(coloc.n_scramble), normed=True)

# Plot computed r
ax.plot([coloc.pearson_r, coloc.pearson_r], ax.get_ylim(), 'r-')

# Label axes
ax.set_xlabel('Pearson $r$')

# %% [markdown]
# Even though the Pearson $r$ is "low" (≈0.08), it is still far beyond what we would get by random localization of pixels, so we are more or less 100% sure there is colocalization.

# %% [markdown]
# ### Determining what pixels are colocated

# %% [markdown]
# The Costes method features an algorithm on how to specify which pixels are colocalized.  It goes as follows.  Let $I_g$ be the set of pixel intensities in the green channel and $I_r$ be the set of pixel intensities in the red channel.
# 1. Perform a regression based on all points of to give $I_g = a I_r + b$.
# 2. Define $T = \max(I_r)$.
# 3. Compute The Pearson $r$ value considering all pixels with $I_r < T$ and $I_g < aT + b$.
# 4. If $r \le r_\mathrm{thresh}$ (typically $r_\mathrm{thresh} = 0$), decrement $T$ and goto 3.  Otherwise, save $T_r = T$ and $T_g = aT + b$.
# 5. Pixels with $I_g > T_g$ and $I_r > T_r$ are colocalized.
#
# The method then labels pixels with high intensity in both channels as colocalized.

# %% [markdown]
# ### The Manders coefficients

# %% [markdown]
# The **Manders coefficient** is defined as the intensity-weighted fraction of pixels that are colocalized.
#
# \begin{align}
# M_r = \frac{\sum_{i_\mathrm{coloc}}I_{r,i}}{\sum_i I_{r,i}},
# \end{align}
#
# where the top sum is over colocalized pixels.  A similar definition applies for $M_g$. Note that $M_r \ne M_g$ in general.  E.g., imagine there are several red puncta in an image and a few green ones, but the green ones are always colocalized with the red.  Then, $M_g \approx 1$, but $M_r$ may be small.
#
# The colocalized pixels are determined using Costes's method and then the Manders coefficients are computed using the `jb_costes.costes_coloc` function.

# %%
# Use costes module to perform colocalization
coloc = jb_costes.costes_coloc(im_r, im_g, n_scramble=200, psf_width=3,
                               do_manders=True, roi=roi, roi_method='all')

# Print results
print("""
Pearson r = {0:.2f}
prob of colocalization = {1:.2f}
Manders coefficient for red = {2:.2f}
Manders coefficient for green = {3:.2f}
""".format(coloc.pearson_r, coloc.p_coloc, coloc.M_1, coloc.M_2))
# Out:
# Pearson r = 0.08
# prob of colocalization = 1.00
# Manders coefficient for red = 0.14
# Manders coefficient for green = 0.14

# %% [markdown]
# Finally, we can view the colocalizated pixels in the merged image by setting their values to white.

# %%
# Make merged image
merged_image = im_merge(im_g, im_r, im_b)

# Inds that will be white
inds = (im_r > coloc.thresh_1) & (im_g > coloc.thresh_2)

# Convert inds to white
merged_image[inds,:] = 1.0

# Show the result
fig, ax = plt.subplots(1, 1, figsize=(9,9))
ax.imshow(merged_image)

# %% [markdown]
# ## When we can't see it

# %% [markdown]
# As a final demonstration, we'll perform a colocalization analysis on images where we can't readily see the colocalization.

# %%
# Generate random images
im_1 = np.random.randint(0, 256, (256, 256))
im_2 = np.random.randint(0, 256, (256, 256))

# Make some pixels the same
psf_width = 5
n_same = int(0.03 * 256**2 / psf_width**2)
for i in range(n_same):
    i = np.random.randint(0, 256-psf_width)
    j = np.random.randint(0, 256-psf_width)
    p = np.random.randint(0, 200)
    im_1[i:i+psf_width, j:j+psf_width] = p
    im_2[i:i+psf_width, j:j+psf_width] = p

# Show images and regions where the are exacly colocated
figure, ax = plt.subplots(1, 3, figsize=(12, 8))
ax[0].imshow(im_1, cmap=cm.gray)
ax[1].imshow(im_2, cmap=cm.gray)
ax[2].imshow(im_1==im_2, cmap=cm.gray)

# %% [markdown]
# Hard to see by eye!  Let's compute the colocalization!

# %%
coloc = jb_costes.costes_coloc(im_1, im_2, n_scramble=200, psf_width=5,
                               thresh_r=0.0, roi=None, do_manders=True)

# Print results
print("""
Pearson r = {0:.2f}
prob of colocalization = {1:.2f}
""".format(coloc.pearson_r, coloc.p_coloc))
# Out:
# Pearson r = 0.02
# prob of colocalization = 1.00

# %% [markdown]
# Remember, the computer can "see" better than we can!
